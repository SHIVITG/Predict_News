# %%
import pandas as pd
import numpy as np
import csv
import seaborn as sns
import matplotlib.pyplot
import re
from nltk import word_tokenize
from collections import Counter
from nltk.corpus import stopwords
import string
import emoji

# %%
#---------------------------------------------------------
#Regex for punctuations,Html tags and extra spaces | Start
#---------------------------------------------------------

PeriodPattern='[.*]$'
CommaPattern='[,*]'
QuestionMarkPattern='[?*]$'
ExclamationPattern='[!*]'
ApostrophePattern="['*]"
QuotationMarkPattern='["*]'
ColonPattern='[:*]'
SemiColonPattern='[;*]'
HyphenPattern='[-*]'
EnDashPattern='[–*]'
EmDashPattern='[—*]'
CurveBracketsPattern='[()*]'
SquareBracketsOpenPattern='[[*]'
SquareBracketsClosePattern='[]*]'
EllipsisPattern='[...*]'
HtmlTag = 'html_tag'
HtmltagPattern = '<.*?>'
ExtraSpacePattern=' +'
HashTagPattern='#(\w+[^\s]+)'
AlphaNumPattern='[^A-Za-z0-9]+'
UpperCasePattern='([A-Z][^A-Z]*)'
DigitPattern='(?<=\\D)(?=\\d)|(?<=\\d)(?=\\D)'
#-------------------------------------------------------
#Regex for punctuations,Html tags and extra spaces | End
#-------------------------------------------------------

#-------------------------------------------------
#Global variables for Flags | Start
#-------------------------------------------------
FileReplacedAfter="File is replaced after {}"
FileHasNoChanges="File has no changes."
#-------------------------------------------------
#Global variables for Flags | End
#-------------------------------------------------

# %%
def read_data(file_name):
    data = pd.read_csv(file_name)
    return data

# %%
def remove_html(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, 'html_tags', str(text))

def remove_html_tags(file_name,column_name):
    data=read_data(file_name)
    data[column_name] = data[column_name].str.replace('<[^<]+?>', '')
    #data.to_csv(file_name,index=False) 
    return data

# %%
remove_html_tags("google_news1.csv",'content')
# Out:
#                  region               source  \
# 0     Republic of Korea              Reuters
# 1     Republic of Korea              Reuters
# 2     Republic of Korea  The Washington Post
# 3     Republic of Korea           Xataka.com
# 4     Republic of Korea             Heise.de
# ...                 ...                  ...
# 5035            Nigeria                Wired
# 5036            Nigeria                Wired
# 5037            Nigeria            The Verge
# 5038            Nigeria            The Verge
# 5039            Nigeria            The Verge
#
#                                                     url             author  \
# 0     https://www.reuters.com/article/us-china-healt...  Reuters Editorial
# 1     https://www.reuters.com/article/us-china-healt...  Reuters Editorial
# 2     https://www.washingtonpost.com/health/the-big-...      Linda Searing
# 3     https://www.xataka.com/empresas-y-economia/ind...        Jose García
# ...

# %%
data['content'].to_csv("test.csv",index = False)
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
